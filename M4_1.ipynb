# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 7A74-7975
#
#  Directory of C:\Users\cobbl\Desktop\DSS_UMSL\Jup
#
# 02/10/2025  06:03 PM    <DIR>          .
# 02/03/2025  09:35 PM    <DIR>          ..
# 02/10/2025  06:01 PM    <DIR>          .ipynb_checkpoints
# 02/03/2025  08:42 PM           256,928 Crowdfunding_data_1000_projects.csv
# 02/03/2025  08:33 PM           194,327 Crowdfunding_data_1000_projects.xlsx
# 02/03/2025  09:32 PM            53,190 M3-1.ipynb
# 02/10/2025  06:03 PM           214,112 M4_1.ipynb
# 02/03/2025  08:44 PM           261,561 modified_data.csv
# 02/03/2025  08:46 PM           257,670 modified_file.csv
# 02/03/2025  08:50 PM             5,480 multiple_filters.xlsx
# 02/03/2025  08:47 PM            44,181 Pandas_part_1.ipynb
# 02/03/2025  09:28 PM           112,727 Pandas_part_2.ipynb
# 02/03/2025  08:55 PM            37,336 Pandas_part_3.ipynb
# 02/10/2025  05:53 PM           176,002 Train_test_split.ipynb
# ...

# %%
c_data=pd.read_excel('Crowdfunding_data_1000_projects.xlsx')

# %%
c_data
# Out:
#      Project_ID  school_latitude  school_longitude     school_city  \
# 0             1        45.310140        -93.807736      Monticello
# 1             2        29.795216        -95.358101         Houston
# 2             3        37.754852       -122.426160   San Francisco
# 3             4        36.297083       -119.789619         Lemoore
# 4             5        33.946010       -118.223360      South Gate
# ..          ...              ...               ...             ...
# 995         996        27.712243        -97.425700  Corpus Christi
# 996         997        35.957050        -80.019836      High Point
# 997         998        42.156029        -71.565903      Dorchester
# 998         999        42.926026        -85.626478    Grand Rapids
# 999        1000        41.780422        -87.596931         Chicago
#
#     school_state  school_zip school_metro                 school_district  \
# 0             MN       55362          NaN  Monticello Ind School Dist 882
# ...

# %%
df1=c_data.head(700)

# %%
df1
# Out:
#      Project_ID  school_latitude  school_longitude    school_city  \
# 0             1        45.310140        -93.807736     Monticello
# 1             2        29.795216        -95.358101        Houston
# 2             3        37.754852       -122.426160  San Francisco
# 3             4        36.297083       -119.789619        Lemoore
# 4             5        33.946010       -118.223360     South Gate
# ..          ...              ...               ...            ...
# 695         696        31.987975        -95.308576   Jacksonville
# 696         697        35.323464        -97.459378          Moore
# 697         698        35.479055        -80.603251     Kannapolis
# 698         699        39.966972        -75.204872   Philadelphia
# 699         700        42.315485        -83.281814       Dearborn
#
#     school_state  school_zip school_metro                 school_district  \
# 0             MN       55362          NaN  Monticello Ind School Dist 882
# ...

# %%
df2=c_data.tail(300)

# %%
df2
# Out:
#      Project_ID  school_latitude  school_longitude     school_city  \
# 700         701        35.396235       -120.858074       Morro Bay
# 701         702        46.081711        -88.632727      Iron River
# 702         703        39.088215        -76.822835          Laurel
# 703         704        38.489349       -121.485954      Sacramento
# 704         705        36.032299       -115.238316       Las Vegas
# ..          ...              ...               ...             ...
# 995         996        27.712243        -97.425700  Corpus Christi
# 996         997        35.957050        -80.019836      High Point
# 997         998        42.156029        -71.565903      Dorchester
# 998         999        42.926026        -85.626478    Grand Rapids
# 999        1000        41.780422        -87.596931         Chicago
#
#     school_state  school_zip school_metro                 school_district  \
# 700           CA       93442          NaN  San Luis Coastal Unif Sch Dist
# ...

# %%
df1=c_data.sample(700)

# %%
df1
# Out:
#      Project_ID  school_latitude  school_longitude    school_city  \
# 966         967        31.146218        -97.905283  Copperas Cove
# 661         662        42.647581        -71.349560         Lowell
# 415         416        36.737635       -119.734332         Fresno
# 820         821        41.599236        -87.349060           Gary
# 772         773        36.136047       -115.321152      Las Vegas
# ..          ...              ...               ...            ...
# 594         595        40.641032        -73.993402  New York City
# 6             7        40.942077        -73.870718        Yonkers
# 240         241        37.779919       -122.435585  San Francisco
# 480         481        40.729717        -73.983969  New York City
# 638         639        44.133465        -70.495067         Oxford
#
#     school_state  school_zip school_metro                 school_district  \
# 966           TX       76522     suburban  Copperas Cove Ind Sch District
# ...

# %%
df2=c_data.drop(df1.index)

# %%
df2
# Out:
#      Project_ID  school_latitude  school_longitude    school_city  \
# 2             3        37.754852       -122.426160  San Francisco
# 3             4        36.297083       -119.789619        Lemoore
# 12           13        35.898918        -77.842346    Rocky Mount
# 15           16        38.885948        -81.119576     Mount Zion
# 16           17        38.808087        -91.139267      Warrenton
# ..          ...              ...               ...            ...
# 977         978        38.887047        -76.939590            NaN
# 982         983        47.925217        -97.033125    Grand Forks
# 985         986        26.480263        -80.113770   Delray Beach
# 990         991        41.822464       -111.827060     Smithfield
# 998         999        42.926026        -85.626478   Grand Rapids
#
#     school_state  school_zip school_metro                 school_district  \
# 2             CA       94114        urban  San Francisco Unified Sch Dist
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df1, df2 = train_test_split(c_data, test_size=0.3)

# %%
df1
# Out:
#      Project_ID  school_latitude  school_longitude    school_city  \
# 676         677        34.275037        -88.579692     Mooreville
# 15           16        38.885948        -81.119576     Mount Zion
# 824         825        40.824965        -73.905977  New York City
# 802         803        39.407359        -74.526054  Pleasantville
# 620         621        40.607165        -73.986820  New York City
# ..          ...              ...               ...            ...
# 624         625        32.751338       -117.107402      San Diego
# 120         121        41.921853        -87.681259        Chicago
# 511         512        40.729717        -73.983969  New York City
# 709         710        33.489723       -112.176376        Phoenix
# 118         119        38.602707       -121.351170     Carmichael
#
#     school_state  school_zip school_metro                school_district  \
# 676           MS       38857        rural         Lee Co School District
# ...

# %%
df2
# Out:
#      Project_ID  school_latitude  school_longitude    school_city  \
# 64           65        39.773575       -105.002953         Denver
# 758         759        33.980186        -98.529160  Wichita Falls
# 281         282        36.503592        -77.639999         Gaston
# 494         495        39.936558        -75.153735   Philadelphia
# 405         406        43.636195       -116.603073          Nampa
# ..          ...              ...               ...            ...
# 822         823        40.033500        -75.037717   Philadelphia
# 278         279        35.788055        -82.033035         Marion
# 717         718        42.011021        -71.494522     Woonsocket
# 706         707        41.918535        -87.683356        Chicago
# 893         894        41.453234        -74.447382     Middletown
#
#     school_state  school_zip school_metro                school_district  \
# 64            CO       80211        urban    Denver Public School Dist 1
# ...
